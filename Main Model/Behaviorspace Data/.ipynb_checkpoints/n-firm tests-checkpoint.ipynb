# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('multifirm_baseline baseline_varying_firm_number.csv', error_bad_lines=False)
df['firm-turnover'] = df['[mean]'] / df['n-firms'] / 2
display(df)
# Out:
#    [run number]  replace-exited-firm?  allow-firm-exit?  n-firms  \
# 0             1                  True              True       20
# 1             2                  True              True       40
# 2             3                  True              True       60
# 3             4                  True              True       80
# 4             5                  True              True      100
# 5             6                  True              True      120
# 6             7                  True              True      140
# 7             8                  True              True      160
# 8             9                  True              True      180
# 9            10                  True              True      200
#
#    transactions-per-month  n-households setup-structure  use-index?  \
# 0                       1           500       two-layer        True
# 1                       1           500       two-layer        True
# ...

# %%
ax = sns.scatterplot(x= "n-firms", 
                     y= "firm-turnover", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. mean firm turnover")
plt.show()
