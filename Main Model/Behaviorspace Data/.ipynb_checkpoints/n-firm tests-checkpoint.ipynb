# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Singlefirm_varying_firm_number.csv', error_bad_lines=False)
df['firm-turnover'] = df['[mean] bankrupt'] / df['n-firms']
df['max-firm-turnover'] = df['[max]'] / df['n-firms']
df['unemployment'] = 1 - (df['[mean] employed?'] / 1000)
df['total-bankrupt-firms'] = df['[mean] bankrupt'] * 201

display(df)
# Out:
#     [run number]  replace-exited-firm?  allow-firm-exit?  n-firms  \
# 0              1                  True              True       40
# 1              2                  True              True       60
# 2              3                  True              True       80
# 3              4                  True              True      100
# 4              5                  True              True      120
# 5              6                  True              True      140
# 6              7                  True              True      160
# 7              8                  True              True      180
# 8              9                  True              True      200
# 9             10                  True              True      220
# 10            11                  True              True      240
# 11            12                  True              True      260
# 12            13                  True              True      280
# ...

# %%
ax = sns.scatterplot(x= "n-firms", 
                     y= "firm-turnover", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. mean firm turnover (n-households = 1,000)")
plt.show()

ax2 = sns.scatterplot(x= "n-firms", 
                     y= "unemployment", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. mean unemployment (n-households = 1,000)")
plt.show()

ax3 = sns.scatterplot(x= "n-firms", 
                     y= "price", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. price (n-households = 1,000)")
plt.show()

ax4 = sns.scatterplot(x= "n-firms", 
                     y= "profits", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. profits (n-households = 1,000)")
plt.show()

# %%
df = pd.read_csv('multifirm_baseline single-firm_varying_firm_number-table.csv', sep='joursep', header=0)
# Out:
# <ipython-input-2-71d65a18a633>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('multifirm_baseline single-firm_varying_firm_number-table.csv', sep='joursep', header=4)
