# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('single-firm_varying_firm_number.csv', error_bad_lines=False, header=6)  
df['firm-turnover'] = df['TOTAL-BANKRUPT-FIRMS / n-firms'] / 400
df['unemployment'] = 1 - df['count households with [employed?]'] / 1000


display(df)
# Out:
#     [run number]  n-firms  transactions-per-month  n-households  \
# 0              1       20                       1           500
# 1              2       30                       1           500
# 2              3       40                       1           500
# 3              4       50                       1           500
# 4              5       60                       1           500
# 5              6       70                       1           500
# 6              7       80                       1           500
# 7              8       90                       1           500
# 8             11      120                       1           500
# 9             10      110                       1           500
# 10             9      100                       1           500
# 11            13      140                       1           500
# 12            12      130                       1           500
# 13            14      150                       1           500
# ...

# %%
ax = sns.scatterplot(x= "n-firms", 
                     y= "firm-turnover", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. mean firm turnover (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "unemployment", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. unemployment (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean [price] of firms", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. price (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean ALL-FIRM-PROFITS", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. ALL FIRM PROFITS (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean BANKRUPT-FIRM-PROFITS", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. BANKRUPT FIRM PROFITS (n-households = 500)")
plt.show()

# %%
df = pd.read_csv('single-firm_low_firm_number.csv', error_bad_lines=False, header=6)  
df['firm-turnover'] = df['TOTAL-BANKRUPT-FIRMS / n-firms'] / 200
df = df.replace(['<RuntimePrimitiveException>'], 0.0)
df['mean BANKRUPT-FIRM-PROFITS'] = df['mean BANKRUPT-FIRM-PROFITS'].astype(float)

display(df)
# Out:
#     [run number]  n-firms  transactions-per-month  n-households  \
# 0              7       16                       1           500
# 1              4       13                       1           500
# 2              1       10                       1           500
# 3              6       15                       1           500
# 4              5       14                       1           500
# 5              8       17                       1           500
# 6              3       12                       1           500
# 7              2       11                       1           500
# 8              9       18                       1           500
# 9             10       19                       1           500
# 10            11       20                       1           500
# 11            12       21                       1           500
# 12            13       22                       1           500
# 13            15       24                       1           500
# ...

# %%
ax = sns.scatterplot(x= "n-firms", 
                     y= "firm-turnover", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. mean firm turnover (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean UNEMPLOYMENT-RATES", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. unemployment (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean MEAN-PRICES", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. price (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean ALL-FIRM-PROFITS", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. ALL FIRM PROFITS (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean BANKRUPT-FIRM-PROFITS", 
                     data = df)
plt.title("One-Layer Firm: n-firms vs. BANKRUPT FIRM PROFITS (n-households = 500)")
plt.show()

# %%
df = pd.read_csv('double-firm_low_firm_number.csv', error_bad_lines=False, header=6)  
df = df.replace(['<RuntimePrimitiveException>'], 0.0)
df['mean BANKRUPT-FIRM-PROFITS'] = df['mean BANKRUPT-FIRM-PROFITS'].astype(float)
df['firm-turnover'] = df['TOTAL-BANKRUPT-FIRMS / n-firms'] / 200


display(df)
# Out:
#     [run number]  n-firms  transactions-per-month  n-households  \
# 0              2       11                       1           500
# 1              4       13                       1           500
# 2              7       16                       1           500
# 3              8       17                       1           500
# 4              3       12                       1           500
# 5              6       15                       1           500
# 6              5       14                       1           500
# 7              1       10                       1           500
# 8              9       18                       1           500
# 9             10       19                       1           500
# 10            11       20                       1           500
# 11            12       21                       1           500
# 12            13       22                       1           500
# 13            14       23                       1           500
# ...

# %%
ax = sns.scatterplot(x= "n-firms", 
                     y= "firm-turnover", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. mean firm turnover (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean UNEMPLOYMENT-RATES", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. unemployment (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean MEAN-PRICES", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. price (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean ALL-FIRM-PROFITS", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. ALL FIRM PROFITS (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean BANKRUPT-FIRM-PROFITS", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. BANKRUPT FIRM PROFITS (n-households = 500)")
plt.show()

# %%
df = pd.read_csv('double-firm_varying_firm_number.csv', error_bad_lines=False, header=6)  
df = df.replace(['<RuntimePrimitiveException>'], 0.0)
df['mean BANKRUPT-FIRM-PROFITS'] = df['mean BANKRUPT-FIRM-PROFITS'].astype(float)
df['firm-turnover'] = df['TOTAL-BANKRUPT-FIRMS / n-firms'] / 200


display(df)
# Out:
#     [run number]  n-firms  transactions-per-month  n-households  \
# 0              2       30                       1           500
# 1              1       20                       1           500
# 2              3       40                       1           500
# 3              4       50                       1           500
# 4              6       70                       1           500
# 5              5       60                       1           500
# 6              7       80                       1           500
# 7              8       90                       1           500
# 8              9      100                       1           500
# 9             11      120                       1           500
# 10            10      110                       1           500
# 11            12      130                       1           500
# 12            13      140                       1           500
# 13            14      150                       1           500
# ...

# %%
ax = sns.scatterplot(x= "n-firms", 
                     y= "firm-turnover", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. mean firm turnover (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean UNEMPLOYMENT-RATES", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. unemployment (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean MEAN-PRICES", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. price (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean ALL-FIRM-PROFITS", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. ALL FIRM PROFITS (n-households = 500)")
plt.show()

ax = sns.scatterplot(x= "n-firms", 
                     y= "mean BANKRUPT-FIRM-PROFITS", 
                     data = df)
plt.title("Two-Layer Firm: n-firms vs. BANKRUPT FIRM PROFITS (n-households = 500)")
plt.show()
